# %%
%help
# Out:
# CRN Kernel - Available Directives:
#
# %crn                 - Use CRN (Chemical Reaction Networks) syntax
# %dsd                 - Use DSD (DNA Strand Displacement) syntax
# %reset               - Reset material state only (keeps macro definitions)
# %reset state         - Reset material state only (keeps macro definitions)
# %reset all           - Reset all state (including macro definitions)
# %help                - Show this help message
# %csv                 - Enable CSV export for current cell (default: disabled)
# %title "name"        - Set custom title for CSV export (used with %csv)
# %export expanded     - Export and display the expanded macro code
# %debug on|off        - Enable or disable debug output (default: off)
# %macro reset         - Reset macro registry only (clear all defined macros)
# %macro list          - List all defined macros
#
# Macro Definition and Usage:
#   %define Name (input1, input2) :(output1, output2)
#     // CRN code here
#   %end define
#
# ...

# %%
directive simulation { 
  final=600; 
  plots=[Input1; Input2; Output; Signal];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]
| 100 Reporter 
| 100 Join
| 10 Input2
| 10 Input1
| Reporter + Output ->{k} sp2 + Signal
| Join + Input1 <->{k}{k} sp4 + sp3
| sp4 + Input2 <->{k}{k} sp1 + Output
# Out:
# Material state reset (macros and settings preserved).
# [DEBUG processCode] code.Length = 325
# [DEBUG processCode] codeWithoutDefs.Length = 325
# [DEBUG processCode] fullExpandedCode.Length = 325
# [DEBUG processCode] registry.Instances.Count = 0
# [DEBUG processCode] registry.Definitions.Count = 0
# [DEBUG] === Simulation Parameters ===
# [DEBUG] Simulator: Oslo
# [DEBUG] Time: initial=0.000000, final=600.000000
# [DEBUG] Points: 1000
# [DEBUG] Stochastic Scale: 1.000000
# [DEBUG] Plots: { name = "Input1" }, { name = "Input2" }, { name = "Output" }, { name = "Signal" }
#
# [DEBUG] === Species and Initial Concentrations ===
# [DEBUG]   Reporter: 100
# [DEBUG]   Join: 100
# [DEBUG]   Input2: 10
# [DEBUG]   Input1: 10
# [DEBUG]   Output: 0
# [DEBUG]   sp2: 0
# [DEBUG]   Signal: 0
# [DEBUG]   sp4: 0
# [DEBUG]   sp3: 0
# [DEBUG]   sp1: 0
#
# [DEBUG] === Reactions (3 total) ===
#
# [DEBUG] Using Simulator: Oslo
# [DEBUG] CRN settings simulator: Oslo
# ...

# %%
%reset all
%csv
%title 测试
directive simulation { 
  final=600; 
  plots=[Input1; Input2; Output; Signal];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]
| 100 Reporter 
| 100 Join
| 10 Input2
| 10 Input1
| Reporter + Output ->{k} sp2 + Signal
| Join + Input1 <->{k}{k} sp4 + sp3
| sp4 + Input2 <->{k}{k} sp1 + Output
# Out:
# All state reset (including macros and settings).
#
# === CSV Exported ===
# Saved to: d:\Test\crn\crn-engine\CRNKernel\测试_20260319_182420.csv
# Final Species Concentrations:
# ...
# Input1              : 0.0633299
# Input2              : 0.634046
# Output              : 0.00365645
# Signal              : 9.3623
# Simulation completed successfully.
#
# Time range: 0.00 to 600.00
# Number of time points: 1001 (requested: 1000)
#
# Number of species: 4
#
# Final concentrations:
#   Input1: 0.0633299
#   Input2: 0.634046
#   Output: 0.00365645
#   Signal: 9.3623

# %% [markdown]
# 下一步增加调试信息输出的%控制

# %%
directive simulation { 
  final=600; 
  plots=[Input1; Input2; Output; Signal];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]
| 100 Reporter 
| 100 Join
| 10 Input2
| 10 Input1
| Reporter + Output ->{k} sp2 + Signal
| Join + Input1 <->{k}{k} sp4 + sp3
| sp4 + Input2 <->{k}{k} sp1 + Output
# Out:
# === State from Previous Run (old = last new or 0) ===
#   Input1: 0.063330
#   Input2: 0.634046
#   Output: 0.003656
#   Signal: 9.362298
# Final Species Concentrations:
# ...
# Input1              : 0.0398868
# Input2              : 0.965537
# Output              : 0.00346544
# Signal              : 19.031
# Simulation completed successfully.
#
# Time range: 0.00 to 600.00
# Number of time points: 1001 (requested: 1000)
#
# Number of species: 4
#
# Final concentrations:
#   Input1: 0.0398868
#   Input2: 0.965537
#   Output: 0.00346544
#   Signal: 19.031

# %%
%reset all
%define ADD(A,B):(Y)
directive parameters [ k = 0.003;]
| 10 C

|A->{k}A+Y
|B->{k}B+Y
|Y->{k}C
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%define COPY(A):(B)
directive parameters [ k = 0.003;]
|A->{k}A+B
|B->{k}
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%define MUL(A,B):(Y)
directive parameters [ k = 0.3;]

|A+B->{k}A+B+Y
|Y->{k}
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 3
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%define ADD(A,B):(Y)
directive parameters [ k = 0.003;]

|A->{k}A+Y
|B->{k}B+Y
|Y->{k}
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 3
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 3
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%define MAC(A,W1,B,W2):(Y)
directive parameters [ k = 0.003;]

| 0 Y1
| 0 Y2
%invoke MUL(A,W1):(Y1)
%invoke MUL(B,W2):(Y2)
%invoke ADD(Y1,Y2):(Y)

%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 3
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 3
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
# ...

# %%
%export expanded
%debug off
directive simulation { 
  final=5000; 
  plots=[Input1; Input2; Output];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

| 1 Input2
| 2 Input1
| 3 C
| 4 D
| 0 Output

%invoke MAC(Input1,C,Input2,D):(Output)
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 3
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 3
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
# ...

# %%
%export expanded
%reset 

%debug off
directive simulation { 
  final=1600; 
  plots=[Input1; Input2; Output];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

| 10 Input2
| 10 Input1
| 0 Output

%invoke ADD(Input1,Input2):(Output)
# Out:
# Material state reset (macros and settings preserved).
# Debug output disabled.
# // Registered Macros:
# //   ADD(A, B) :(Y)
# //     OK
# //   COPY(A) :(B)
# //     OK
# //   MUL(A, B) :(Y)
# //     OK
# //   MAC(A, W1, B, W2) :(Y)
# //     OK
#
# // Full Expanded Code:
#
# directive simulation {
#   final=1600;
#   plots=[Input1; Input2; Output];
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
# | 10 Input2
# | 10 Input1
# | 0 Output
#
# // === BEGIN MACRO EXPANSION: ADD_1 (ADD) ===
#
#
# |Input1->{0.003}Input1+Output
# |Input2->{0.003}Input2+Output
# |Output->{0.003}
# // === END MACRO EXPANSION: ADD_1 ===
#
#
#
# // Macro Instances:
# //   MUL_0:
# //     Inputs: map [("A", "A"); ("B", "W1")]
# //     Outputs: map [("Y", "Y1")]
# //     Local Params: [("k", "0.3")]
# //   MUL_1:
# //     Inputs: map [("A", "B"); ("B", "W2")]
# //     Outputs: map [("Y", "Y2")]
# //     Local Params: [("k", "0.3")]
# //   ADD_0:
# ...

# %%
directive simulation { 
  final=1600; 
  plots=[Input1; Input2; Output];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

| 10 Input2
| 10 Input1
| 0 Output

%invoke ADD(Input1,Input2):(Output)
# Out:
# === State from Previous Run (old = last new or 0) ===
#   Input1: 10.000000
#   Input2: 10.000000
#   Output: 19.835065
# Final Species Concentrations:
# ...
# Input1              : 20
# Input2              : 20
# Output              : 39.8337
# Simulation completed successfully.
#
# Time range: 0.00 to 1600.00
# Number of time points: 1001 (requested: 1000)
#
# Number of species: 3
#
# Final concentrations:
#   Input1: 20
#   Input2: 20
#   Output: 39.8337

# %% [markdown]
# 湮灭反应

# %%
%reset
directive simulation { 
  final=5000; 
  plots=[Input1; Input2; ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

| 1 Input2
| 2 Input1


| Input1 + Input2->{k}
# Out:
# Material state reset (macros and settings preserved).
# Final Species Concentrations:
# ...
# Input1              : 1
# Input2              : 1.46749e-07
# Simulation completed successfully.
#
# Time range: 0.00 to 5000.00
# Number of time points: 1001 (requested: 1000)
#
# Number of species: 2
#
# Final concentrations:
#   Input1: 1
#   Input2: 1.46749e-07

# %%
%reset all
%define ADD0(A,B):(Y)
directive parameters [ k = 0.003;]

|A->{k}A+Y
|B->{k}B+Y
|Y->{k}
%end define
%define ADD(A0,A1,B0,B1):(Y0,Y1)
directive parameters [ k = 0.003;]

%invoke ADD0(A0,B0):(Y0)
%invoke ADD0(A1,B1):(Y1)
|Y0+Y1->{k}
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
directive simulation { 
  final=5000; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 1 A0
| 2 A1
| 3 B0
| 5 B1
| 0 c0
| 0 c1
| 0 c
%invoke ADD(A0,A1,B0,B1):(c0,c1)
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# Final Species Concentrations:
# ...
# [res]               : -3
# Simulation completed successfully.
#
# Time range: 0.00 to 5000.00
# Number of time points: 1001 (requested: 1000)
#
# Number of species: 1
#
# Final concentrations:
#   [res]: -3

# %%
%define MUL0(A,B):(Y)
directive parameters [ k = 0.03;]
|A+B->{k}A+B+Y
|Y->{k}
%end define

%define MUL(A0,A1,B0,B1):(Y0,Y1)
directive parameters [ k = 0.03;]
| 0 TMP1
| 0 TMP2
| 0 TMP3
| 0 TMP4
%invoke MUL0(A0,B0):(TMP1)
%invoke MUL0(A1,B1):(TMP2)
%invoke ADD0(TMP1,TMP2):(Y0)
%invoke MUL0(A0,B1):(TMP3)
%invoke MUL0(A1,B0):(TMP4)
%invoke ADD0(TMP3,TMP4):(Y1)
|Y0+Y1->{k}
%end define
# Out:
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=5000; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 1 A0
| 2 A1
| 3 B0
| 5 B1
| 0 c0
| 0 c1
| 0 c
%invoke MUL(A0,A1,B0,B1):(c0,c1)
# Out:
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   ADD0(A, B) :(Y)
# //     OK
# //   ADD(A0, A1, B0, B1) :(Y0, Y1)
# //     OK
# //   MUL0(A, B) :(Y)
# //     OK
# //   MUL(A0, A1, B0, B1) :(Y0, Y1)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=5000;
#   plots=[res ];
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
# directive rates [
# 	res = [c0]-[c1];
# ]
#
# | 1 A0
# | 2 A1
# | 3 B0
# | 5 B1
# | 0 c0
# | 0 c1
# | 0 c
# // === BEGIN MACRO EXPANSION: MUL_0 (MUL) ===
#
# | 0 MUL_0_local_TMP1
# | 0 MUL_0_local_TMP2
# | 0 MUL_0_local_TMP3
# | 0 MUL_0_local_TMP4
# // === BEGIN MACRO EXPANSION: MUL0_0 (MUL0) ===
#
# |A0+B0->{0.03}A0+B0+MUL_0_local_TMP1
# |MUL_0_local_TMP1->{0.03}
# ...

# %%
%define TANH_ZERO(NETp, NETm):(Hp, Hm)
directive parameters [ k = 1.0; ]

// 零级反应需要催化剂饱和，这里用近似实现
// 创建一个"时间控制"物种 T_CTRL，初始浓度 = NETp
| NETp -> {k} T_CTRL  // 复制 NET 到时间控制器

// 零级降解 (需要高浓度催化剂饱和，这里用近似)
| T_CTRL -> {k}       // 近似零级

// 用 T_CTRL 催化 tanh 反应
| T_CTRL -> {k} T_CTRL + Hp
| T_CTRL + Hp + Hp -> {k} T_CTRL + Hp
| T_CTRL -> {k}

// 负半轴对称
| NETm -> {k} T_CTRL_M
| T_CTRL_M -> {k}
| T_CTRL_M -> {k} T_CTRL_M + Hm
| T_CTRL_M + Hm + Hm -> {k} T_CTRL_M + Hm
| T_CTRL_M -> {k}

| Hp + Hm -> {k}
%end define
# Out:
# Macro definitions registered: 5
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
directive simulation { 
  final=5000; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 5 A0
| 3 A1

| 0 c0
| 0 c1

%invoke TANH(A0,A1):(c0,c1)
# Out:
# ❌ Macro Expansion: Error processing macros: Macro 'TANH' is not defined
#
# Failed to expand macros:
# Error processing macros: Macro 'TANH' is not defined
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Detailed Traceback:

# %%
%reset all

%define ADD(A,B):(Y)
directive parameters [ k = 0.3;]

|A->{k}A+Y
|B->{k}B+Y
|Y->{k}
%end define
%define EXP(X):(Y)
directive parameters [
  k1 = 100.0;
  k2 = 10.0;
  k3 = 1.0;
  k4 = 1.0;
  k5 = 0.0864;
  k6 = 1.020;
  k7 = 8.580;
  k8 = 22.46;
  E0 = 1.0;
  C0 = 5.0;
  Y0 = 3.218;
]


| E0 E
| 0 TE
| C0 C
| 0 TC
| Y0 Y
| 0 T
| 0 Y_2

| X ->{k1} T

| T + E <->{k2}{k3} TE

| TE ->{k4} E

| T + C <->{k5}{k6} TC

| C ->{k7}

| Y + TC ->{k8} 2Y + TC
//%invoke ADD(Y_1,Y_2):(Y)
%end define
# Out:
# Macro definitions registered: 5
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# All state reset (including macros and settings).
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %% [markdown]
# 上面的Y必须被宏覆盖初始值，不然计算是错误的，或者可以考虑copy

# %%
%reset all

%define COPY(A):(B)
directive parameters [ k = 0.3;]
|A->{k}A+B
|B->{k}
%end define
%define EXP(X):(YO)
directive parameters [
  k1 = 100.0;
  k2 = 10.0;
  k3 = 1.0;
  k4 = 1.0;
  k5 = 0.0864;
  k6 = 1.020;
  k7 = 8.580;
  k8 = 22.46;
  E0 = 1.0;
  C0 = 5.0;
  Y0 = 3.218;
]


| E0 E
| 0 TE
| C0 C
| 0 TC
| Y0 Y
| 0 T
| 0 Y_2

| X ->{k1} T

| T + E <->{k2}{k3} TE

| TE ->{k4} E

| T + C <->{k5}{k6} TC

| C ->{k7}

| Y + TC ->{k8} 2Y + TC
%invoke COPY(Y):(YO)
%end define
# Out:
# Macro definitions registered: 5
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# All state reset (including macros and settings).
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# All state reset (including macros and settings).
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=60; 
  plots=[X;Y ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]


| 20 X
| 0 Y

%invoke EXP(X):(Y)
# Out:
# Macro definitions registered: 5
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# All state reset (including macros and settings).
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# All state reset (including macros and settings).
# Macro definitions registered: 2
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   COPY(A) :(B)
# //     OK
# //   EXP(X) :(YO)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=60;
#   plots=[X;Y ];
# }
# ...

# %%
%reset
directive simulation {
  final = 60.0;
  plots = [X; T; E; TE; C; TC; Y];
  points = 1001;
}

directive simulator deterministic

directive parameters [
  k1 = 100.0;
  k2 = 10.0;
  k3 = 1.0;
  k4 = 1.0;
  k5 = 0.0864;
  k6 = 1.020;
  k7 = 8.580;
  k8 = 22.46;
  X0 = 20.0;
  E0 = 1.0;
  C0 = 5.0;
  Y0 = 3.218;
]

// Initial concentrations
| X0 X
| E0 E
| 0 TE
| C0 C
| 0 TC
| Y0 Y
| 0 T

// R1: X -> T (input encoding)
| X ->{k1} T

// R2: T + E <-> TE (Michaelis-Menten buffer)
| T + E <->{k2}{k3} TE

// R3: TE -> E (catalytic release, consumes T)
| TE ->{k4} E

// R4: T + C <-> TC (catalyst activation)
| T + C <->{k5}{k6} TC

// R5: C -> null (catalyst degradation, time window control)
| C ->{k7}

// R6: Y + TC -> 2Y + TC (autocatalytic amplification)
| Y + TC ->{k8} 2Y + TC
# Out:
# Material state reset (macros and settings preserved).
# Final Species Concentrations:
# ...
# C                   : 1.78934e-27
# E                   : 1
# T                   : 4.74684e-08
# TC                  : 1.32622e-26
# TE                  : -5.21686e-08
# X                   : 0
# Y                   : 4.67172e+08
# Simulation completed successfully.
#
# Time range: 0.00 to 60.00
# Number of time points: 1002 (requested: 1001)
#
# Number of species: 7
#
# Final concentrations:
#   C: 1.78934e-27
#   E: 1
#   T: 4.74684e-08
#   TC: 1.32622e-26
#   TE: -5.21686e-08
#   X: 0
#   Y: 4.67172e+08

# %%
// Full Expanded Code:
%reset all
directive simulation { 
  final=6000; 
  plots=[X;Y ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]


| 20 X
| 0 Y



// === BEGIN MACRO EXPANSION: EXP_0 (EXP) ===



| 1.0 EXP_0_local_E
| 0 EXP_0_local_TE
| 5.0 EXP_0_local_C
| 0 EXP_0_local_TC
| 3.218 EXP_0_local_Y
| 0 EXP_0_local_T
| 0 EXP_0_local_Y_2

| X ->{100.0} EXP_0_local_T

| EXP_0_local_T + EXP_0_local_E <->{10.0}{1.0} EXP_0_local_TE

| EXP_0_local_TE ->{1.0} EXP_0_local_E

| EXP_0_local_T + EXP_0_local_C <->{0.0864}{1.020} EXP_0_local_TC

| EXP_0_local_C ->{8.580}

| EXP_0_local_Y + EXP_0_local_TC ->{22.46} 2EXP_0_local_Y + EXP_0_local_TC
// === BEGIN MACRO EXPANSION: COPY_0 (COPY) ===

|EXP_0_local_Y->{0.3}EXP_0_local_Y+Y
|Y->{0.3}
// === END MACRO EXPANSION: COPY_0 ===

// === END MACRO EXPANSION: EXP_0 ===
# Out:
# All state reset (including macros and settings).
# Final Species Concentrations:
# ...
# X                   : 0
# Y                   : 4.67172e+08
# Simulation completed successfully.
#
# Time range: 0.00 to 6000.00
# Number of time points: 1001 (requested: 1000)
#
# Number of species: 2
#
# Final concentrations:
#   X: 0
#   Y: 4.67172e+08

# %%
%reset all
%define COPY(A):(B)
directive parameters [ k = 0.003;]
|A->{k}A+B
|B->{k}
%end define

%define ADD0(A,B):(Y)
directive parameters [ k = 0.003;]
|A->{k}A+Y
|B->{k}B+Y
|Y->{k}
%end define

%define ADD(A0,A1,B0,B1):(Y0,Y1)
directive parameters [ k = 0.003;]
%invoke ADD0(A0,B0):(Y0)
%invoke ADD0(A1,B1):(Y1)
|Y0+Y1->{k}
%end define


%define MUL0(A,B):(Y)
directive parameters [ k = 0.03;]
|A+B->{k}A+B+Y
|Y->{k}
%end define

%define MUL(A0,A1,B0,B1):(Y0,Y1)
directive parameters [ k = 0.03;]
| 0 TMP1
| 0 TMP2
| 0 TMP3
| 0 TMP4
%invoke MUL0(A0,B0):(TMP1)
%invoke MUL0(A1,B1):(TMP2)
%invoke ADD0(TMP1,TMP2):(Y0)
%invoke MUL0(A0,B1):(TMP3)
%invoke MUL0(A1,B0):(TMP4)
%invoke ADD0(TMP3,TMP4):(Y1)
|Y0+Y1->{k}
%end define



%define MAC(A0,W0,A1,W1,B0,W2,B1,W3):(Y0,Y1)
directive parameters [ k = 0.003;]

| 0 Y3
| 0 Y4
| 0 Y5
| 0 Y6
%invoke MUL(A0,W0,A1,W1):(Y3,Y4)
%invoke MUL(B0,W2,B1,W3):(Y5,Y6)
%invoke ADD(Y3,Y4,Y5,Y6):(Y0,Y1)
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 6
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %% [markdown]
# # MAC 测试

# %%
%reset
%export expanded
directive simulation { 
  final=5000; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 1 A0
| 2 A1
| 3 B0
| 5 B1
| 2 W0
| 3 W1
| 6 W2
| 3 W3
| 0 c0
| 0 c1
| 0 c
%invoke MAC(A0,W0,A1,W1,B0,W2,B1,W3):(c0,c1)
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 6
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   COPY(A) :(B)
# //     OK
# //   ADD0(A, B) :(Y)
# //     OK
# //   ADD(A0, A1, B0, B1) :(Y0, Y1)
# //     OK
# //   MUL0(A, B) :(Y)
# //     OK
# //   MUL(A0, A1, B0, B1) :(Y0, Y1)
# //     OK
# //   MAC(A0, W0, A1, W1, B0, W2, B1, W3) :(Y0, Y1)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=5000;
#   plots=[res ];
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
# directive rates [
# 	res = [c0]-[c1];
# ]
#
# | 1 A0
# | 2 A1
# | 3 B0
# | 5 B1
# | 2 W0
# | 3 W1
# | 6 W2
# | 3 W3
# | 0 c0
# | 0 c1
# | 0 c
# // === BEGIN MACRO EXPANSION: MAC_0 (MAC) ===
#
#
# | 0 MAC_0_local_Y3
# ...

# %%
%reset all
%define TANH(N0,N1):(H0,H1)
directive parameters [ k = 0.3]
| 0 H0
| 0 H1
| 0 H0
| 0 H1
//正分量逻辑 (对应 dH0/dt = k*N0*(1 - H0^2))
|N0->{k}N0+H0
|N0+H0+H0->{k}N0+H0
|N0->{k}
//负分量逻辑 (对应 dH1/dt = k*N1*(1 - H1^2))
|N1->{k}N1+H1
|N1+H1+H1->{k}N1+H1
|N1->{k}
//双轨湮灭 (确保 H0 和 H1 不会同时存在)
|H0+H1->{k}
%end define

%define SIGMOID(N0,N1):(H0,H1)
directive parameters [ k = 0.03;]
| 0.5 H0
| 0.5 H1
//正分量逻辑 (对应 dH0/dt = k*N0*(H0 - H0^2))
|N0+H0->{k}N0+H0+H0
|N0+H0+H0->{k}N0+H0
|N0->{k}
//负分量逻辑 (对应 dH1/dt = k*N1*(H1 - H1^2))
|N1+H1->{k}N1+H1+H1
|N1+H1+H1->{k}N1+H1
|N1->{k}
//双轨湮灭
|H0+H1->{k}
%end define

%define LAYER(N0,N1,W0,W1,W2,W3,W4,W5,W6,W7):(Y0,Y1)
directive parameters [ k = 0.003;]
| 0 Y3
| 0 Y4
| 0 Y5
| 0 Y6
//加权求和 (复用提供的 MAC 宏)
//注意：这里假设 MAC 宏输出的是双轨净输入 (Net Input)
// 如果 MAC 宏输出直接作为激活函数输入，需确保物种命名匹配
//此处为了演示链路，假设 MAC 输出为 Y3,Y4 (正负)
//实际使用时请将 MAC 的输出连接到 TANH/SIGMOID 的输入
%invoke MAC(N0,W0,N1,W1,Y3,W4,Y4,W5):(Y5,Y6) 
//上面这行是示例，实际需根据您的 MAC 宏定义调整参数顺序
//此处直接调用激活函数示例：
//invoke TANH(N0,N1):(Y0,Y1)
%end define

%define ACTIVATED_MAC(A0,W0,A1,W1,B0,W2,B1,W3):(Y0,Y1)
directive parameters [ k = 0.003;]
| 0 Y3
| 0 Y4
| 0 Y5
| 0 Y6
//第一步：加权求和 (产生净输入 Net Input)
%invoke MAC(A0,W0,A1,W1,B0,W2,B1,W3):(Y3,Y4)
//第二步：激活函数 (消耗净输入 Y3,Y4，产生激活输出 Y0,Y1)
//注意：TANH 宏会消耗输入 Y3,Y4，符合论文中 Input Degradation 的设计
%invoke TANH(Y3,Y4):(Y0,Y1)
%end define

%define ACTIVATED_MAC_SIG(A0,W0,A1,W1,B0,W2,B1,W3):(Y0,Y1)
directive parameters [ k = 0.003;]
| 0 Y3
| 0 Y4
//第一步：加权求和
%invoke MAC(A0,W0,A1,W1,B0,W2,B1,W3):(Y3,Y4)
//第二步：Sigmoid 激活 (初始浓度 0.5)
%invoke SIGMOID(Y3,Y4):(Y0,Y1)
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 5
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=90; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 0.5 A0
| 0 A1
| 0 c1
| 0 c
%invoke TANH(A0,A1):(c0,c1)
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 5
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   TANH(N0, N1) :(H0, H1)
# //     OK
# //   SIGMOID(N0, N1) :(H0, H1)
# //     OK
# //   LAYER(N0, N1, W0, W1, W2, W3, W4, W5, W6, W7) :(Y0, Y1)
# //     OK
# //   ACTIVATED_MAC(A0, W0, A1, W1, B0, W2, B1, W3) :(Y0, Y1)
# //     OK
# //   ACTIVATED_MAC_SIG(A0, W0, A1, W1, B0, W2, B1, W3) :(Y0, Y1)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=90;
#   plots=[res ];
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
# directive rates [
# 	res = [c0]-[c1];
# ]
#
# | 0.5 A0
# | 0 A1
# | 0 c1
# | 0 c
# // === BEGIN MACRO EXPANSION: TANH_0 (TANH) ===
#
# | 0 c0
# | 0 c1
# | 0 c0
# | 0 c1
# ...

# %%
%reset all
%define TANH(N0,N1):(H0,H1)
directive parameters [ k = 0.2;k2=100000]
//必须要这么大的速率湮灭才能吗？
| 0 H0
| 0 H1
| 0 H0
| 0 H1
| N0+N1->{k2}
//正分量逻辑 (对应 dH0/dt = k*N0*(1 - H0^2))
|N0->{k}N0+H0
|N0+H0+H0->{k}N0+H0
|N0->{k}
//负分量逻辑 (对应 dH1/dt = k*N1*(1 - H1^2))
|N1->{k}N1+H1
|N1+H1+H1->{k}N1+H1
|N1->{k}
//双轨湮灭 (确保 H0 和 H1 不会同时存在)
|H0+H1->{k}
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=90; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 0.5 A0
| 1 A1
| 0 c1
| 0 c
%invoke TANH(A0,A1):(c0,c1)
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   TANH(N0, N1) :(H0, H1)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=90;
#   plots=[res ];
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
# directive rates [
# 	res = [c0]-[c1];
# ]
#
# | 0.5 A0
# | 1 A1
# | 0 c1
# | 0 c
# // === BEGIN MACRO EXPANSION: TANH_0 (TANH) ===
#
# //必须要这么大的速率湮灭才能吗？
# | 0 c0
# | 0 c1
# | 0 c0
# | 0 c1
# | A0+A1->{100000}
# //正分量逻辑 (对应 dH0/dt = 0.2*A0*(1 - c0^2))
# |A0->{0.2}A0+c0
# |A0+c0+c0->{0.2}A0+c0
# |A0->{0.2}
# //负分量逻辑 (对应 dH1/dt = 0.2*A1*(1 - c1^2))
# |A1->{0.2}A1+c1
# |A1+c1+c1->{0.2}A1+c1
# |A1->{0.2}
# //双轨湮灭 (确保 c0 和 c1 不会同时存在)
# |c0+c1->{0.2}
# ...

# %%
%reset all
%define TANH_CLK(N0,N1,CLK_BASE):(H0,H1)
directive parameters [ k = 0.03; k_ann = 0.3; ]

// === 相位 C3: 输入互斥湮灭 ===
| CLK_BASE+2 + N0 + N1 ->{k_ann} CLK_BASE+2 + waste

// === 相位 C5: 输出预清除 ===
| CLK_BASE+4 + H0 ->{k_ann} CLK_BASE+4
| CLK_BASE+4 + H1 ->{k_ann} CLK_BASE+4
| CLK_BASE+4 + H0 + H1 ->{k_ann} CLK_BASE+4

// === 相位 C7: 主计算（Tanh 正分量）===
| CLK_BASE+6 + N0 ->{k} CLK_BASE+6 + N0 + H0
| CLK_BASE+6 + N0 + H0 + H0 ->{k} CLK_BASE+6 + N0 + H0
| CLK_BASE+6 + N0 ->{k} CLK_BASE+6

// === 相位 C7: 主计算（Tanh 负分量）===
| CLK_BASE+6 + N1 ->{k} CLK_BASE+6 + N1 + H1
| CLK_BASE+6 + N1 + H1 + H1 ->{k} CLK_BASE+6 + N1 + H1
| CLK_BASE+6 + N1 ->{k} CLK_BASE+6

// === 相位 C9: 输出互斥湮灭 ===
| CLK_BASE+8 + H0 + H1 ->{k_ann} CLK_BASE+8
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=90; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 0.5 A0
| 1 A1
| 0 c1
| 0 c
%invoke TANH_CLK(A0,A1):(c0,c1)
# Out:
# ❌ Macro Expansion: Error processing macros: Macro 'TANH_CLK' expects 3 input parameters, got 2
#
# Failed to expand macros:
# Error processing macros: Macro 'TANH_CLK' expects 3 input parameters, got 2
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Detailed Traceback:

# %%
%reset all
directive simulation { 
  final=2000; 
  plots=[C1; C2; C3; C4; C5; C6; C7; C8; C9; C10; C11; C12; C13; C14; C15; C16; C17; C18; C19; C20];
}
directive simulator deterministic
directive parameters [ k_clock = 0.1 ]

// 初始条件：C19 和 C20 设为高浓度 (1.0)，其余为低浓度 (10^-6)
| 1.0 C19
| 1.0 C20
| 0.000001 C1
| 0.000001 C2
| 0.000001 C3
| 0.000001 C4
| 0.000001 C5
| 0.000001 C6
| 0.000001 C7
| 0.000001 C8
| 0.000001 C9
| 0.000001 C10
| 0.000001 C11
| 0.000001 C12
| 0.000001 C13
| 0.000001 C14
| 0.000001 C15
| 0.000001 C16
| 0.000001 C17
| 0.000001 C18

// 分子时钟反应：20 相位振荡器 (Section II.C)
// 反应模式为 Ci + C(i+1) -> C(i+1) + C(i+1)，形成循环催化
| C1 + C2 ->{k_clock} C2 + C2
| C2 + C3 ->{k_clock} C3 + C3
| C3 + C4 ->{k_clock} C4 + C4
| C4 + C5 ->{k_clock} C5 + C5
| C5 + C6 ->{k_clock} C6 + C6
| C6 + C7 ->{k_clock} C7 + C7
| C7 + C8 ->{k_clock} C8 + C8
| C8 + C9 ->{k_clock} C9 + C9
| C9 + C10 ->{k_clock} C10 + C10
| C10 + C11 ->{k_clock} C11 + C11
| C11 + C12 ->{k_clock} C12 + C12
| C12 + C13 ->{k_clock} C13 + C13
| C13 + C14 ->{k_clock} C14 + C14
| C14 + C15 ->{k_clock} C15 + C15
| C15 + C16 ->{k_clock} C16 + C16
| C16 + C17 ->{k_clock} C17 + C17
| C17 + C18 ->{k_clock} C18 + C18
| C18 + C19 ->{k_clock} C19 + C19
| C19 + C20 ->{k_clock} C20 + C20
| C20 + C1 ->{k_clock} C1 + C1
# Out:
# All state reset (including macros and settings).
# Final Species Concentrations:
# ...
# C1                  : 9.99194e-07
# C10                 : 9.99608e-07
# C11                 : 9.99613e-07
# C12                 : 9.99597e-07
# C13                 : 9.99607e-07
# C14                 : 9.99625e-07
# C15                 : 9.99687e-07
# C16                 : 4.99768e-07
# C17                 : 4.99391e-07
# C18                 : 9.99103e-07
# C19                 : 9.99201e-07
# C2                  : 9.99202e-07
# C20                 : 9.99185e-07
# C3                  : 9.99207e-07
# C4                  : 9.992e-07
# C5                  : 1.00125e-06
# C6                  : 0.00409891
# C7                  : 1.99541
# C8                  : 0.000488841
# C9                  : 9.99834e-07
# Simulation completed successfully.
#
# Time range: 0.00 to 2000.00
# Number of time points: 1001 (requested: 1000)
#
# Number of species: 20
#
# Final concentrations:
#   C1: 9.99194e-07
# ...

# %%
%reset all
%define BASE_CLOCK(c1,c2,c3,c4):(c1,c2,c3,c4)
directive parameters [ k_clock = 0.1 ]

| c1 + c2 ->{k_clock} c2 + c2
| c2 + c3 ->{k_clock} c3 + c3
| c3 + c4 ->{k_clock} c4 + c4
| c4 + c1 ->{k_clock} c1 + c1 
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=900; 
  plots=[c1;c2;c3;c4 ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]


| 1 c1
| 1 c2
| 1e-6 c3
| 1e-6 c4
%invoke BASE_CLOCK(c1,c2,c3,c4):(c1,c2,c3,c4)
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 1
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   BASE_CLOCK(c1, c2, c3, c4) :(c1, c2, c3, c4)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=900;
#   plots=[c1;c2;c3;c4 ];
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
#
# | 1 c1
# | 1 c2
# | 1e-6 c3
# | 1e-6 c4
# // === BEGIN MACRO EXPANSION: BASE_CLOCK_0 (BASE_CLOCK) ===
#
#
# | c1 + c2 ->{0.1} c2 + c2
# | c2 + c3 ->{0.1} c3 + c3
# | c3 + c4 ->{0.1} c4 + c4
# | c4 + c1 ->{0.1} c1 + c1
# // === END MACRO EXPANSION: BASE_CLOCK_0 ===
#
#
#
# // Macro Instances:
# //   BASE_CLOCK_0:
# //     Inputs: map [("c1", "c1"); ("c2", "c2"); ("c3", "c3"); ("c4", "c4")]
# ...

# %%
%reset all
%define BASE_CLOCK(c1,c2,c3,c4):(c1,c2,c3,c4)
directive parameters [ k_clock = 0.1 ]
| c1 + c2 ->{k_clock} c2 + c2
| c2 + c3 ->{k_clock} c3 + c3
| c3 + c4 ->{k_clock} c4 + c4
| c4 + c1 ->{k_clock} c1 + c1 
%end define

%define SUB_CLOCK(C_base):(c1,c2,c3,c4)
directive parameters [ k_clock = 1 ]
// 调用需要手动设置c1,c2,c3,c4浓度，低相位设定为1e-6，高相位设定为1
| C_base+c1 + c2 ->{k_clock} C_base+c2 + c2
| C_base+c2 + c3 ->{k_clock} C_base+c3 + c3
| C_base+c3 + c4 ->{k_clock} C_base+c4 + c4
| C_base+c4 + c1 ->{k_clock} C_base+c1 + c1 
%end define

%define THREE_CLOCK(c1,c2,c3):(c1,c2,c3)
directive parameters [ k_clock = 0.1 ]
| c1 + c2 ->{k_clock} c2 + c2
| c2 + c3 ->{k_clock} c3 + c3
| c3 + c1 ->{k_clock} c1 + c1
%end define

%define TANH(N0,N1):(H0,H1)
directive parameters [ k = 0.2]
//必须要这么大的速率湮灭才能吗？
| 0 H0
| 0 H1
| 1 c1
| 1e-6 c2
| 1 c3
%invoke THREE_CLOCK(c1,c2,c3):(c1,c2,c3)
| c1+N0+N1->{k}c1
//正分量逻辑 (对应 dH0/dt = k*N0*(1 - H0^2))
|c2+N0->{k}c2+N0+H0
|N0+H0+H0+c2->{k}c2+N0+H0
|N0+c2->{k}c2
//负分量逻辑 (对应 dH1/dt = k*N1*(1 - H1^2))
|N1+c2->{k}N1+H1+c2
|N1+H1+H1+c2->{k}N1+H1+c2
|N1+c2->{k}c2
//双轨湮灭 (确保 H0 和 H1 不会同时存在)
|H0+H1+c3->{k}c3
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=5000; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 4 A0
| 0 A1
| 0 c1
| 0 c0
%invoke TANH(A0,A1):(c0,c1)
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   BASE_CLOCK(c1, c2, c3, c4) :(c1, c2, c3, c4)
# //     OK
# //   SUB_CLOCK(C_base) :(c1, c2, c3, c4)
# //     OK
# //   THREE_CLOCK(c1, c2, c3) :(c1, c2, c3)
# //     OK
# //   TANH(N0, N1) :(H0, H1)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=5000;
#   plots=[res ];
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
# directive rates [
# 	res = [c0]-[c1];
# ]
#
# | 4 A0
# | 0 A1
# | 0 c1
# | 0 c0
# // === BEGIN MACRO EXPANSION: TANH_0 (TANH) ===
#
# //必须要这么大的速率湮灭才能吗？
# | 0 c0
# | 0 c1
# | 1 TANH_0_local_c1
# | 1e-6 TANH_0_local_c2
# | 1 TANH_0_local_c3
# ...

# %% [markdown]
# # 双时钟测试

# %%
%reset all
%define SUB_THREE_CLOCK(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
directive parameters [ k_clock = 0.1 ]
| c1 + c2 + CB ->{k_clock} c2 + c2+ CB
| c2 + c3+ CB ->{k_clock} c3 + c3+ CB
| c3 + c4 + CB->{k_clock} c4 + c4+ CB
| c4 + c5 + CB ->{k_clock} c5 + c5+ CB
| c5 + c6+ CB ->{k_clock} c6 + c6+ CB
| c6 + c1 + CB->{k_clock} c1 + c1+ CB
%end define
%define SUB_THREE_CLOCK2(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
directive parameters [ k_clock = 1 ]
| c1 + c2 + CB ->{k_clock} c2 + c2+ CB
| c2 + c3+ CB ->{k_clock} c3 + c3+ CB
| c3 + c4 + CB->{k_clock} c4 + c4+ CB
| c4 + c5 + CB ->{k_clock} c5 + c5+ CB
| c5 + c6+ CB ->{k_clock} c6 + c6+ CB
| c6 + c1 + CB->{k_clock} c1 + c1+ CB
%end define

%define sub_test(CB):()
| 1 c1
| 1e-6 c2
| 1e-6 c3
| 1e-6 c4
| 1e-6 c5
| 1 c6
%invoke SUB_THREE_CLOCK2(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
%end define
%define test_clock(CB):()
| 1 c1
| 1e-6 c2
| 1e-6 c3
| 1e-6 c4
| 1e-6 c5
| 1 c6
%invoke SUB_THREE_CLOCK(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
//第一阶段
%invoke sub_test(c1):()

//第三阶段
%invoke sub_test(c3):()
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
directive simulation { 
  final=200; 
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

| 1 CB

%invoke test_clock(CB):()
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 4
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   SUB_THREE_CLOCK(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   SUB_THREE_CLOCK2(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   sub_test(CB) :()
# //     OK
# //   test_clock(CB) :()
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=200;
# }
# directive simulator deterministic
# directive parameters [ k = 0.003; u = 0.1 ]
#
# | 1 CB
#
# // === BEGIN MACRO EXPANSION: test_clock_0 (test_clock) ===
# | 1 test_clock_0_local_c1
# | 1e-6 test_clock_0_local_c2
# | 1e-6 test_clock_0_local_c3
# | 1e-6 test_clock_0_local_c4
# | 1e-6 test_clock_0_local_c5
# | 1 test_clock_0_local_c6
# ...

# %% [markdown]
# # 神经元测试

# %%
%reset all
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 0
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%debug off
%define SUB_THREE_CLOCK(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
directive parameters [ k_clock = 0.035 ]
| c1 + c2 + CB ->{k_clock} c2 + c2+ CB
| c2 + c3+ CB ->{k_clock} c3 + c3+ CB
| c3 + c4 + CB->{k_clock} c4 + c4+ CB
| c4 + c5 + CB ->{k_clock} c5 + c5+ CB
| c5 + c6+ CB ->{k_clock} c6 + c6+ CB
| c6 + c1 + CB->{k_clock} c1 + c1+ CB
%end define
%define SUB_THREE_CLOCK2(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
directive parameters [ k_clock = 1 ]
| c1 + c2 + CB ->{k_clock} c2 + c2+ CB
| c2 + c3+ CB ->{k_clock} c3 + c3+ CB
| c3 + c4 + CB->{k_clock} c4 + c4+ CB
| c4 + c5 + CB ->{k_clock} c5 + c5+ CB
| c5 + c6+ CB ->{k_clock} c6 + c6+ CB
| c6 + c1 + CB->{k_clock} c1 + c1+ CB
%end define
%define ADD0C(A,B,CB):(Y,CB)
directive parameters [ k = 2;]
|CB+A->{k}CB+A+Y
|CB+B->{k}CB+B+Y
|CB+Y->{k}CB
%end define

%define ADDCC(A0,A1,B0,B1,C1,C2):(Y0,Y1,C1,C2)
//C1先执行，C2后执行,先加和再湮灭
directive parameters [ k = 2;]
%invoke ADD0C(A0,B0,C1):(Y0,C1)
%invoke ADD0C(A1,B1,C1):(Y1,C1)
|C2+Y0+Y1->{k}C2
%end define
%define ADDC(A0,A1,B0,B1,CB):(Y0,Y1,CB)
directive parameters [ k = 2;]
%invoke ADD0C(A0,B0,CB):(Y0,CB)
%invoke ADD0C(A1,B1,CB):(Y1,CB)
|CB+Y0+Y1->{k}CB
%end define

%define MUL0C(A,B,CB):(Y,CB)
directive parameters [ k = 2;]
|A+B+CB->{k}A+B+Y+CB
|Y+CB->{k}CB
%end define

%define MULCC(A0,A1,B0,B1,C1,C2):(Y0,Y1,C1,C2)
directive parameters [ k = 2;]
| 0 TMP1
| 0 TMP2
| 0 TMP3
| 0 TMP4
//一阶段计算没有遇到次序问题
%invoke MUL0C(A0,B0,C1):(TMP1,C1)
%invoke MUL0C(A1,B1,C1):(TMP2,C1)
%invoke MUL0C(A0,B1,C1):(TMP3,C1)
%invoke MUL0C(A1,B0,C1):(TMP4,C1)
%invoke ADD0C(TMP1,TMP2,C1):(Y0,C1)
%invoke ADD0C(TMP3,TMP4,C1):(Y1,C1)
|Y0+Y1+C2->{k}C2
%end define

%define MULC(A0,A1,B0,B1,CB):(Y0,Y1,CB)
//不需要内部时钟的版本
directive parameters [ k = 2;]
| 0 TMP1
| 0 TMP2
| 0 TMP3
| 0 TMP4
%invoke MUL0C(A0,B0,CB):(TMP1,CB)
%invoke MUL0C(A1,B1,CB):(TMP2,CB)
%invoke MUL0C(A0,B1,CB):(TMP3,CB)
%invoke MUL0C(A1,B0,CB):(TMP4,CB)
%invoke ADD0C(TMP1,TMP2,CB):(Y0,CB)
%invoke ADD0C(TMP3,TMP4,CB):(Y1,CB)
%end define


%define MACC(A0,W0,A1,W1,B0,W2,B1,W3,CB):(Y0,Y1,CB)
directive parameters [ k = 2;]

| 0 Y3
| 0 Y4
| 0 Y5
| 0 Y6
%invoke MULC(A0,A1,W0,W1,CB):(Y3,Y4,CB)
%invoke MULC(B0,B1,W2,W3,CB):(Y5,Y6,CB)
%invoke ADDC(Y3,Y4,Y5,Y6,CB):(Y0,Y1,CB)
%end define

%define TANHC(N0,N1,CB):(H0,H1,CB)
directive parameters [ k = 2]
| 1 c1
| 1e-6 c2
| 1e-6 c3
| 1e-6 c4
| 1e-6 c5
| 1 c6

%invoke SUB_THREE_CLOCK2(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)

| c3+N0+N1+CB->{k}c3+CB
//正分量逻辑 (对应 dH0/dt = k*N0*(1 - H0^2))
|c5+N0+CB->{k}c5+N0+H0+CB
|N0+H0+H0+c5+CB->{k}c5+N0+H0+CB
|N0+c5+CB->{k}c5+CB
//负分量逻辑 (对应 dH1/dt = k*N1*(1 - H1^2))
|N1+c5+CB->{k}N1+H1+c5+CB
|N1+H1+H1+c5+CB->{k}N1+H1+c5+CB
|N1+c5+CB->{k}c5+CB

%end define

%define NEURON(X0P,X0N,W0P,W0N,X1P,X1N,W1P,W1N,WP,WN,CB):(YP,YN,CB)
//需要三时钟
| 1 c1
| 1e-6 c2
| 1e-6 c3
| 1e-6 c4
| 1e-6 c5
| 1 c6
| 0 YTMP
| 0 Y0
| 0 Y1
| 0 YTMP0
| 0 YTMP1

%invoke SUB_THREE_CLOCK(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
//第一步，MAC计算
%invoke MACC(X0P,W0P,X0N,W0N,X1P,W1P,X1N,W1N,c1):(Y0,Y1,c1)
//第二步 WP偏置计算
%invoke ADD0C(Y0,WP,c3):(YTMP0,c3)
%invoke ADD0C(Y1,WN,c3):(YTMP1,c3)
//第二步tanh计算
%invoke TANHC(YTMP0,YTMP1,c5):(YP,YN,c5)
%end define

%define NEURON2(X0P,X0N,W0P,W0N,X1P,X1N,W1P,W1N,WP,CB):(YP,YN,CB)
//需要三时钟
| 1 c1
| 1e-6 c2
| 1e-6 c3
| 1e-6 c4
| 1e-6 c5
| 1 c6
| 0 Y0
| 0 Y1
| 0 YTMP1
%invoke SUB_THREE_CLOCK(c1,c2,c3,c4,c5,c6,CB):(c1,c2,c3,c4,c5,c6,CB)
//第一步，MAC计算
%invoke MACC(X0P,W0P,X0N,W0N,X1P,W1P,X1N,W1N,c1):(Y0,Y1,c1)
//第二步 WP偏置计算
%invoke ADD0C(Y1,WP,c2):(YTMP1,c2)
//第三步tanh计算
//%invoke TANHC(Y0,YTMP1,c5):(YP,YN,c5)
%end define
# Out:
# All state reset (including macros and settings).
# Macro definitions registered: 0
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.
# Debug output disabled.
# Macro definitions registered: 12
# No simulation performed (macro definitions only)
#
# Note: Macro definitions are stored but not executed.
#    Use %invoke to call macros in subsequent cells.

# %%
%reset
%export expanded
%csv
%title "XOR"
directive simulation { 
  final=1000; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 1 X1P
| 0 X1N
| 3 W01P
| 1 W01N
| 5 X2P
| 2 X2N
| 4 W11P
| 0 W11N
| 15 W00
| 1 CB
| 0 c1
| 0 c0
%invoke  NEURON(X1P,X1N,W01P,W01N,X2P,X2N,W11P,W11N,W00,CB):(c0,c1,CB)

# %%
%reset
%export expanded
directive simulation { 
  final=100; 
  plots=[Y00; YN1;c0;c1];
  //plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 1 X1P
| 0 X1N
| 3 W01P
| 1 W01N
| 5 X2P
| 2 X2N
| 4 W11P
| 0 W11N
| 10 W00
| 1 CB
| 0 c1
| 0 c0
| 0 Y00
| 0 Y10
| 0 YN1
//%invoke MACC(X1P,W01P,X1N,W01N,X2P,W11P,X2N,W11N,CB):(c0,Y10,CB)
//%invoke ADD0C(Y10,W00,CB):(c1,CB)
%invoke MACC(X1P,W01P,X1N,W01N,X2P,W11P,X2N,W11N,CB):(Y00,Y10,CB)
%invoke ADD0C(Y10,W00,CB):(YN1,CB)
//Y00+YN1->{1000}
%invoke  TANHC(Y00,YN1,CB):(c0,c1,CB)
//%invoke NEURON2(X1P,X1N,W01P,W01N,X2P,X2N,W11P,W11N,W00,CB):(c0,c1,CB)
# Out:
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   SUB_THREE_CLOCK(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   SUB_THREE_CLOCK2(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   ADD0C(A, B, CB) :(Y, CB)
# //     OK
# //   ADDCC(A0, A1, B0, B1, C1, C2) :(Y0, Y1, C1, C2)
# //     OK
# //   ADDC(A0, A1, B0, B1, CB) :(Y0, Y1, CB)
# //     OK
# //   MUL0C(A, B, CB) :(Y, CB)
# //     OK
# //   MULCC(A0, A1, B0, B1, C1, C2) :(Y0, Y1, C1, C2)
# //     OK
# //   MULC(A0, A1, B0, B1, CB) :(Y0, Y1, CB)
# //     OK
# //   MACC(A0, W0, A1, W1, B0, W2, B1, W3, CB) :(Y0, Y1, CB)
# //     OK
# //   TANHC(N0, N1, CB) :(H0, H1, CB)
# //     OK
# //   NEURON(X0P, X0N, W0P, W0N, X1P, X1N, W1P, W1N, WP, WN, CB) :(YP, YN, CB)
# //     OK
# //   NEURON2(X0P, X0N, W0P, W0N, X1P, X1N, W1P, W1N, WP, CB) :(YP, YN, CB)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=100;
# ...

# %%
%reset
%export expanded
directive simulation { 
  final=150; 
  plots=[res ];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

| 5 X1P
| 1 X1N

| 1 CB
| 0 c1
| 0 c0


%invoke  TANHC(X1P,X1N,CB):(c0,c1,CB)
# Out:
# Material state reset (macros and settings preserved).
# // Registered Macros:
# //   SUB_THREE_CLOCK(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   SUB_THREE_CLOCK2(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   ADD0C(A, B, CB) :(Y, CB)
# //     OK
# //   ADDCC(A0, A1, B0, B1, C1, C2) :(Y0, Y1, C1, C2)
# //     OK
# //   ADDC(A0, A1, B0, B1, CB) :(Y0, Y1, CB)
# //     OK
# //   MUL0C(A, B, CB) :(Y, CB)
# //     OK
# //   MULCC(A0, A1, B0, B1, C1, C2) :(Y0, Y1, C1, C2)
# //     OK
# //   MULC(A0, A1, B0, B1, CB) :(Y0, Y1, CB)
# //     OK
# //   MACC(A0, W0, A1, W1, B0, W2, B1, W3, CB) :(Y0, Y1, CB)
# //     OK
# //   TANHC(N0, N1, CB) :(H0, H1, CB)
# //     OK
# //   NEURON(X0P, X0N, W0P, W0N, X1P, X1N, W1P, W1N, WP, WN, CB) :(YP, YN, CB)
# //     OK
# //   NEURON2(X0P, X0N, W0P, W0N, X1P, X1N, W1P, W1N, WP, CB) :(YP, YN, CB)
# //     OK
#
# // Full Expanded Code:
# directive simulation {
#   final=150;
#   plots=[res ];
# }
# ...

# %%
%reset
%export expanded
%csv
%title "XOR Network Implementation (Table S2 Params)"
directive simulation { 
  final=1000; 
  plots=[res];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

// === 1. 输入信号 (假设 X1=1, X2=1) ===
| 0 X1P
| 1 X1N
| 1 X2P
| 0 X2N
| 1 CB

// === 2. 权重定义 (来自论文 Table S2) ===
// 双轨制表示：正权重放入P，负权重放入N

// --- N0 (隐藏层神经元1) 权重 ---
// W01: -0.5547 (负权重 -> N分量)
| 0 W01P
| 0.5547 W01N
// W02: -3.4716 (负权重 -> N分量)
| 0 W02P
| 3.4716 W02N
// W00: -3.3795 (论文中为负，偏置项。此处传入幅值，由宏内部处理符号)
| 3.3795 W00

// --- N1 (隐藏层神经元2) 权重 ---
// W11: 0.16 (正权重 -> P分量)
| 0.16 W11P
| 0 W11N
// W12: -2.39 (负权重 -> N分量)
| 0 W12P
| 2.39 W12N
// W10: 2.81 (论文中为正)
| 2.81 W10

// --- N2 (输出层神经元) 权重 ---
// W21: 3.01 (正权重 -> P分量)
| 3.01 W21P
| 0 W21N
// W22: -2.48 (负权重 -> N分量)
| 0 W22P
| 2.48 W22N
// W20: 2.72 (论文中为正)
| 2.72 W20

// === 3. 中间变量与输出初始化 ===
| 0 H0P
| 0 H0N
| 0 H1P
| 0 H1N
| 0 c1
| 0 c0

// === 4. 神经元调用 (严格遵循10参数签名) ===

// 隐藏层 N0: 输入 X1,X2; 权重 W01,W02; 偏置 W00; 输出 H0
%invoke NEURON(X1P, X1N, W01P, W01N, X2P, X2N, W02P, W02N, W00, CB):(H0P, H0N, CB)

// 隐藏层 N1: 输入 X1,X2; 权重 W11,W12; 偏置 W10; 输出 H1
%invoke NEURON(X1P, X1N, W11P, W11N, X2P, X2N, W12P, W12N, W10, CB):(H1P, H1N, CB)

// 输出层 N2: 输入 H0,H1; 权重 W21,W22; 偏置 W20; 输出 c0,c1
%invoke NEURON(H0P, H0N, W21P, W21N, H1P, H1N, W22P, W22N, W20, CB):(c0, c1, CB)

# %%
%reset 
%debug on
directive simulation { 
  final=2000; 
  plots=[Y_P; Y_N; H0_P; H0_N, H1_P; H1_N];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1]
]	

# ==================== 初始条件 (论文 Table S2 权重) ====================
# 输入信号 (XOR 测试：1, 1 → -1)
| 1 X1_P
| 0 X1_N
| 1 X2_P
| 0 X2_N

# --- 神经元 N0 (隐藏层) 权重 ---
# W01 (X1): -0.5547
| 0 W01_P
| 0.5547 W01_N
# W02 (X2): -3.4716
| 0 W02_P
| 3.4716 W02_N
# W00 (Bias): -3.3795
| 0 W00_P
| 3.3795 W00_N

# --- 神经元 N1 (隐藏层) 权重 ---
# W11 (X1): 0.1598
| 0.1598 W11_P
| 0 W11_N
# W12 (X2): -2.3918
| 0 W12_P
| 2.3918 W12_N
# W10 (Bias): 2.8111
| 2.8111 W10_P
| 0 W10_N

# --- 神经元 N2 (输出层) 权重 ---
# W21 (H0): 3.0070
| 3.0070 W21_P
| 0 W21_N
# W22 (H1): -2.4847
| 0 W22_P
| 2.4847 W22_N
# W20 (Bias): 2.7191
| 2.7191 W20_P
| 0 W20_N

# 时钟/偏置信号
| 1 CB
| 0 c1
| 0 c0

# ==================== 网络实例化 (严格 10 参数) ====================
# 神经元 N0 (隐藏层): X1, X2 → H0
%invoke NEURON(X1_P,X1_N,W01_P,W01_N,X2_P,X2_N,W02_P,W02_N,W00_P,CB):(H0_P,H0_N,CB)

# 神经元 N1 (隐藏层): X1, X2 → H1
%invoke NEURON(X1_P,X1_N,W11_P,W11_N,X2_P,X2_N,W12_P,W12_N,W10_P,CB):(H1_P,H1_N,CB)

# 神经元 N2 (输出层): H0, H1 → Y
%invoke NEURON(H0_P,H0_N,W21_P,W21_N,H1_P,H1_N,W22_P,W22_N,W20_P,CB):(Y_P,Y_N,CB)
# Out:
# ❌ Macro Expansion: Error processing macros: Macro 'NEURON' expects 11 input parameters, got 10
# Macro 'NEURON' expects 11 input parameters, got 10
# Macro 'NEURON' expects 11 input parameters, got 10
#
# Failed to expand macros:
# Error processing macros: Macro 'NEURON' expects 11 input parameters, got 10
# Macro 'NEURON' expects 11 input parameters, got 10
# Macro 'NEURON' expects 11 input parameters, got 10
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋 Detailed Traceback:

# %%
%reset
%export expanded
%csv
%title "XOR Network Initial State (Table S2)"
directive simulation { 
  final=1000; 
  plots=[res];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

// === 1. 输入信号 (假设当前输入为 X1=1, X2=1) ===
// 论文中 True=1, False=-1。这里以 X1P=1 代表 X1=1
| 1 X1P
| 0 X1N
| 1 X2P
| 0 X2N
| 1 CB  // 控制链

// === 2. 权重参数 (来自论文 Table S2) ===
// 精度保留到小数点后两位，便于阅读

// --- 神经元 N0 (隐藏层) 权重 ---
// W01 (X1权重): -0.55 -> 负分量 0.55
| 0 W01P
| 0.55 W01N
// W02 (X2权重): -3.47 -> 负分量 3.47
| 0 W02P
| 3.47 W02N
// W00 (Bias权重): -3.38 -> 负分量 3.38
| 0 W00P
| 3.38 W00N

// --- 神经元 N1 (隐藏层) 权重 ---
// W11 (X1权重): 0.16 -> 正分量 0.16
| 0.16 W11P
| 0 W11N
// W12 (X2权重): -2.39 -> 负分量 2.39
| 0 W12P
| 2.39 W12N
// W10 (Bias权重): 2.81 -> 正分量 2.81
| 2.81 W10P
| 0 W10N

// --- 神经元 N2 (输出层) 权重 ---
// W21 (H0权重): 3.01 -> 正分量 3.01
| 3.01 W21P
| 0 W21N
// W22 (H1权重): -2.48 -> 负分量 2.48
| 0 W22P
| 2.48 W22N
// W20 (Bias权重): 2.72 -> 正分量 2.72
| 2.72 W20P
| 0 W20N

// === 3. 初始状态变量 ===
| 0 c1
| 0 c0
| 0 H0P  // 隐藏层 N0 输出
| 0 H0N
| 0 H1P  // 隐藏层 N1 输出
| 0 H1N

// === 4. 神经元调用 ===

// --- 隐藏层神经元 N0 ---
// 输入: X1, X2, Bias(-1)
// 权重: W01, W02, W00
// 输出: H0 (双轨 H0P, H0N)
%invoke NEURON(X1P, X1N, W01P, W01N, X2P, X2N, W02P, W02N, W00P, W00N, CB):(H0P, H0N, CB)

// --- 隐藏层神经元 N1 ---
// 输入: X1, X2, Bias(-1)
// 权重: W11, W12, W10
// 输出: H1 (双轨 H1P, H1N)
%invoke NEURON(X1P, X1N, W11P, W11N, X2P, X2N, W12P, W12N, W10P, W10N, CB):(H1P, H1N, CB)

// --- 输出层神经元 N2 ---
// 输入: H0, H1, Bias(-1)
// 权重: W21, W22, W20
// 输出: c0, c1 (最终结果)
%invoke NEURON(H0P, H0N, W21P, W21N, H1P, H1N, W22P, W22N, W20P, W20N, CB):(c0, c1, CB)
# Out:
# Material state reset (macros and settings preserved).
# Debug output enabled.
# Material state reset (macros and settings preserved).
# [DEBUG processCode] code.Length = 1589
# [DEBUG processCode] codeWithoutDefs.Length = 1589
# [DEBUG processCode] fullExpandedCode.Length = 32612
# [DEBUG processCode] registry.Instances.Count = 95
# [DEBUG processCode] registry.Definitions.Count = 12
# // Registered Macros:
# //   SUB_THREE_CLOCK(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   SUB_THREE_CLOCK2(c1, c2, c3, c4, c5, c6, CB) :(c1, c2, c3, c4, c5, c6, CB)
# //     OK
# //   ADD0C(A, B, CB) :(Y, CB)
# //     OK
# //   ADDCC(A0, A1, B0, B1, C1, C2) :(Y0, Y1, C1, C2)
# //     OK
# //   ADDC(A0, A1, B0, B1, CB) :(Y0, Y1, CB)
# //     OK
# //   MUL0C(A, B, CB) :(Y, CB)
# //     OK
# //   MULCC(A0, A1, B0, B1, C1, C2) :(Y0, Y1, C1, C2)
# //     OK
# //   MULC(A0, A1, B0, B1, CB) :(Y0, Y1, CB)
# //     OK
# //   MACC(A0, W0, A1, W1, B0, W2, B1, W3, CB) :(Y0, Y1, CB)
# ...

# %%
%reset

directive simulation { 
  final=2000; 
  plots=[Y_P, Y_N, H0_P, H0_N, H1_P, H1_N];
}
directive simulator deterministic
directive parameters [ k = 0.003; u = 0.1 ]

directive rates [
	res = [c0]-[c1];
]	

# ==================== 初始条件 (论文 Table S2 权重) ====================
# 输入信号 (XOR 测试：1, 1 → -1)
| 1 X1_P
| 0 X1_N
| 1 X2_P
| 0 X2_N

# --- 神经元 N0 (隐藏层) 权重 ---
# W01 (X1): -0.5547
| 0 W01_P
| 0.5547 W01_N
# W02 (X2): -3.4716
| 0 W02_P
| 3.4716 W02_N
# W00 (Bias): -3.3795
| 0 W00_P
| 3.3795 W00_N

# --- 神经元 N1 (隐藏层) 权重 ---
# W11 (X1): 0.1598
| 0.1598 W11_P
| 0 W11_N
# W12 (X2): -2.3918
| 0 W12_P
| 2.3918 W12_N
# W10 (Bias): 2.8111
| 2.8111 W10_P
| 0 W10_N

# --- 神经元 N2 (输出层) 权重 ---
# W21 (H0): 3.0070
| 3.0070 W21_P
| 0 W21_N
# W22 (H1): -2.4847
| 0 W22_P
| 2.4847 W22_N
# W20 (Bias): 2.7191
| 2.7191 W20_P
| 0 W20_N

# 时钟/偏置信号
| 1 CB
| 0 c1
| 0 c0

# ==================== 网络实例化 (严格 11 输入 / 3 输出) ====================
# 神经元 N0 (隐藏层): X1, X2 → H0
%invoke NEURON(X1_P,X1_N,W01_P,W01_N,X2_P,X2_N,W02_P,W02_N,W00_P,W00_N,CB):(H0_P,H0_N,CB)

# 神经元 N1 (隐藏层): X1, X2 → H1
%invoke NEURON(X1_P,X1_N,W11_P,W11_N,X2_P,X2_N,W12_P,W12_N,W10_P,W10_N,CB):(H1_P,H1_N,CB)

# 神经元 N2 (输出层): H0, H1 → Y
%invoke NEURON(H0_P,H0_N,W21_P,W21_N,H1_P,H1_N,W22_P,W22_N,W20_P,W20_N,CB):(Y_P,Y_N,CB)
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
